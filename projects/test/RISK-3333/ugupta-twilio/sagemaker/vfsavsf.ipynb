# %%
cadcad
 casdcn vx xv
# Out:
#   Cell In[1], line 2
#     casdcn
#     ^
# IndentationError: unexpected indent

# %%
axadsxadca

# %%
x

# %%
xxa

# %%
nhcdscccdcdscdc

# %%
cdscnfh

# %%
h

# %%
sdccsdcac
nn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cac
#
# NameError: name 'cac' is not defined

# %%
vdfxb dgb

# %%
vsb vksfv b vnxkfjnv fskk nksjn vcksnc s;ub sk vkshf

# %%
cdasLKAJNNVFSMJn v
svn sfmnv K';aesl,vc'liks/nvio'sdnv 
\'
